# %% [markdown]
# COVID 19 DATASET

# %%
import pandas as pd

# %% [markdown]
# IMPORTING THE CSV FILE FROM THE SYSTEM

# %%
data=pd.read_csv(r"C:\Users\Lenovo\Downloads\anudip assignment\Python\Python project\ccovid data set.csv")

# %%
data
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]

# %% [markdown]
# COUNTING THE NUMBER OF NO NULL VALUES IN DIFFERENT COLUMNS OF THE DATA

# %%
data.count()
# Out:
# Date         321
# State        140
# Region       321
# Confirmed    321
# Deaths       321
# Recovered    321
# dtype: int64

# %% [markdown]
# CHECKING NULL VALUES IN EACH COLUMNS

# %% [markdown]
# TRUE SHOWS  NULL VALUE PRESENT AND FALSE SHOWS  NO NULL VALUE PRESENT

# %%
null_matrix = data.isnull()
null_matrix
# Out:
#       Date  State  Region  Confirmed  Deaths  Recovered
# 0    False   True   False      False   False      False
# 1    False   True   False      False   False      False
# 2    False   True   False      False   False      False
# 3    False   True   False      False   False      False
# 4    False   True   False      False   False      False
# ..     ...    ...     ...        ...     ...        ...
# 316  False  False   False      False   False      False
# 317  False  False   False      False   False      False
# 318  False  False   False      False   False      False
# 319  False  False   False      False   False      False
# 320  False  False   False      False   False      False
#
# [321 rows x 6 columns]

# %% [markdown]
# TOTAL COUNT OF NULL VALUES IN EACH COLUMN

# %%
data.isnull().sum()
# Out:
# Date           0
# State        181
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64

# %% [markdown]
# VISUALIZING THE NULL VALUES IN THE STATE COLUMN

# %%
import matplotlib.pyplot as plt
import numpy as np

# Convert boolean DataFrame to integers (0 for False, 1 for True)
null_matrix_int = null_matrix.astype(int)

# Create a figure and axis
fig, ax = plt.subplots(figsize=(12, 8))

# Use imshow to display the null matrix
cax = ax.imshow(null_matrix_int, cmap='cividis', interpolation='nearest')

# Add a colorbar
cbar = plt.colorbar(cax, ax=ax)
cbar.set_label('Null Value Indicator')

# Set axis labels
ax.set_title('Null Values Heatmap')
ax.set_xlabel('Columns')
ax.set_ylabel('Rows')

plt.show()

# %% [markdown]
# => 1) NUMBERS OF CONFIRMED , DEATHS AND RECOVERED CASES IN EACH REGION

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
grouped=data.groupby('Region')

# %%
sum_data=grouped[['Confirmed','Deaths','Recovered']].sum()
sum_data.head(20)
# Out:
#                      Confirmed  Deaths  Recovered
# Region
# Afghanistan               1939      60        252
# Albania                    766      30        455
# Algeria                   3848     444       1702
# Andorra                    743      42        423
# Angola                      27       2          7
# Antigua and Barbuda         24       3         11
# Argentina                 4285     214       1192
# Armenia                   1932      30        900
# Australia                 6752      91       5715
# Austria                  15402     580      12779
# Azerbaijan                1766      23       1267
# Bahamas                     80      11         23
# Bahrain                   2921       8       1455
# Bangladesh                7103     163        150
# Barbados                    80       7         39
# Belarus                  13181      84       2072
# Belgium                  47859    7501      11283
# Belize                      18       2          9
# ...

# %% [markdown]
# IF U WANTS TO SEE THE CASES ONLY CONFIRMED OR DEATHS OR RECOVERED

# %% [markdown]
# CONFIRMED CASES

# %%
sum_data=grouped['Confirmed'].sum()
sum_data
# Out:
# Region
# Afghanistan           1939
# Albania                766
# Algeria               3848
# Andorra                743
# Angola                  27
#                       ...
# West Bank and Gaza     344
# Western Sahara           6
# Yemen                    6
# Zambia                  97
# Zimbabwe                32
# Name: Confirmed, Length: 187, dtype: int64

# %% [markdown]
# BAR CHART FOR CONFIRMED CASES PER REGION

# %%
import matplotlib.pyplot as plt
import numpy as np
regions = ['US', 'India', 'China']  # Replace with your region names
confirmed_cases = np.random.randint(1000)  # Replace with your confirmed case numbers

# plt.figure(figsize=(10, 6))
plt.bar(regions, confirmed_cases, color='blue')
plt.xlabel('Region')
plt.ylabel('Number of Confirmed Cases')
plt.title('Number of Confirmed COVID-19 Cases per Region')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# DEATHS CASES

# %%
sum_data=grouped['Deaths'].sum()
sum_data
# Out:
# Region
# Afghanistan            60
# Albania                30
# Algeria               444
# Andorra                42
# Angola                  2
#                      ...
# West Bank and Gaza      2
# Western Sahara          0
# Yemen                   0
# Zambia                  3
# Zimbabwe                4
# Name: Deaths, Length: 187, dtype: int64

# %% [markdown]
# RECOVERED CASES

# %% [markdown]
# NUMBER OF CASES IN INCREASING ORDER

# %%
sum_data=grouped['Recovered'].sum().sort_values().tail(20)
sum_data
# Out:
# Region
# Israel              8233
# India               8437
# South Korea         9059
# Peru               10037
# Russia             10286
# Belgium            11283
# Mexico             11423
# Austria            12779
# Ireland            13386
# Canada             20327
# Switzerland        22600
# Brazil             34132
# Turkey             44040
# France             49118
# Italy              71252
# Iran               73791
# Mainland China     77610
# Germany           120400
# US                120720
# Spain             132929
# Name: Recovered, dtype: int64

# %% [markdown]
# => 2) REMOVING ALL THE RECORDS WHERE CONFIRMED CASES IS LESS THAN 10

# %%
data[data['Confirmed'] <10]
# Out:
#           Date                             State                 Region  \
# 18   4/29/2020                               NaN                 Bhutan
# 98   4/29/2020                               NaN             MS Zaandam
# 105  4/29/2020                               NaN             Mauritania
# 126  4/29/2020                               NaN       Papua New Guinea
# 140  4/29/2020                               NaN  Sao Tome and Principe
# 177  4/29/2020                               NaN         Western Sahara
# 178  4/29/2020                               NaN                  Yemen
# 184  4/29/2020                          Anguilla                     UK
# 192  4/29/2020  Bonaire, Sint Eustatius and Saba            Netherlands
# 194  4/29/2020            British Virgin Islands                     UK
# 203  4/29/2020      Diamond Princess cruise ship                 Canada
# 272  4/29/2020             Northwest Territories                 Canada
# ...

# %%
data=data[~(data.Confirmed <10)] # To remove the records satisfying a particular condition

# %%
data[data['Confirmed'] <10]
# Out:
# Empty DataFrame
# Columns: [Date, State, Region, Confirmed, Deaths, Recovered]
# Index: []

# %% [markdown]
# => 3)  REGION WHERE MAXIMUM NUMBER OF CONFIRMED  CASES WERE RECORDED

# %%
grouped=data.groupby('Region')
sum_data=grouped['Confirmed'].sum().sort_values(ascending = False )
sum_data.head(20)
# Out:
# Region
# US                1039909
# Spain              236899
# Italy              203591
# France             166536
# UK                 166432
# Germany            161539
# Turkey             117589
# Russia              99399
# Iran                93657
# Mainland China      82861
# Brazil              79685
# Canada              52860
# Belgium             47859
# Netherlands         38993
# Peru                33931
# India               33062
# Switzerland         29407
# Ecuador             24675
# Portugal            24505
# Saudi Arabia        21402
# Name: Confirmed, dtype: int64

# %% [markdown]
# => 4) REGIONS WHERE MINIMUM NUMBER OF DEATHS CASES WERE RECORDED

# %%
grouped=data.groupby('Region')
sum_data=grouped['Deaths'].sum().sort_values()
sum_data.head(60)
# Out:
# Region
# Cambodia                            0
# Seychelles                          0
# Saint Lucia                         0
# Central African Republic            0
# Saint Kitts and Nevis               0
# South Sudan                         0
# Rwanda                              0
# Grenada                             0
# Macau                               0
# Madagascar                          0
# Nepal                               0
# Namibia                             0
# Saint Vincent and the Grenadines    0
# Mozambique                          0
# Holy See                            0
# Timor-Leste                         0
# Mongolia                            0
# Uganda                              0
# Laos                                0
# Eritrea                             0
# Vietnam                             0
# Fiji                                0
# Dominica                            0
# Gambia                              1
# ...

# %% [markdown]
# => 5) HOW MANY CONFIRMED , DEATHS & RECOVERED CASES WERE REPORTED FROM INDIA TILL 29 APRIL 2020 ?

# %% [markdown]
# SO THE DATA USED IN THE DATA SET IS TILL 29/APRIL/2020 ONLY

# %%
data[data.Region == 'India']
# Out:
#          Date State Region  Confirmed  Deaths  Recovered
# 74  4/29/2020   NaN  India      33062    1079       8437

# %% [markdown]
# WE CAN ALSO FETCH RECORDS OF DIFFERENT COUNTRIES LIKE THIS
# EXAMPLE :

# %%
data[data.Region == 'US']
# Out:
#           Date                         State Region  Confirmed  Deaths  \
# 181  4/29/2020                       Alabama     US       6912     256
# 182  4/29/2020                        Alaska     US        355       9
# 186  4/29/2020                       Arizona     US       7209     308
# 187  4/29/2020                      Arkansas     US       3193      57
# 195  4/29/2020                    California     US      48747    1946
# 199  4/29/2020                      Colorado     US      14758     766
# 200  4/29/2020                   Connecticut     US      26767    2169
# 202  4/29/2020                      Delaware     US       4655     144
# 204  4/29/2020  Diamond Princess cruise ship     US         49       0
# 205  4/29/2020          District of Columbia     US       4106     205
# 208  4/29/2020                       Florida     US      33193    1218
# 213  4/29/2020                       Georgia     US      25775    1101
# ...

# %% [markdown]
# => 6) A- SORT THE ENTIRE DATA WRT NO. OF CONFIRMED CASES IN ASCENDING ORDER

# %%
data.sort_values(by = ['Confirmed'],ascending = True ).head(50)
# Out:
#           Date                         State  \
# 156  4/29/2020                           NaN
# 70   4/29/2020                           NaN
# 59   4/29/2020                           NaN
# 318  4/29/2020                         Yukon
# 217  4/29/2020                     Greenland
# 256  4/29/2020                    Montserrat
# 144  4/29/2020                           NaN
# 27   4/29/2020                           NaN
# 306  4/29/2020      Turks and Caicos Islands
# 118  4/29/2020                           NaN
# 215  4/29/2020                Grand Princess
# 206  4/29/2020   Falkland Islands (Malvinas)
# 270  4/29/2020      Northern Mariana Islands
# 136  4/29/2020                           NaN
# 138  4/29/2020                           NaN
# 45   4/29/2020                           NaN
# 201  4/29/2020                       Curacao
# 114  4/29/2020                           NaN
# 137  4/29/2020                           NaN
# 260  4/29/2020                 New Caledonia
# ...

# %% [markdown]
# => 6) B- SORT THE ENTIRE DATA WRT NO. OF RECOVERED CASES IN DESCENDING ORDER

# %%
data.sort_values(by = ['Recovered'],ascending = False ).head(50)
# Out:
#           Date            State                Region  Confirmed  Deaths  \
# 153  4/29/2020              NaN                 Spain     236899   24275
# 61   4/29/2020              NaN               Germany     161539    6467
# 76   4/29/2020              NaN                  Iran      93657    5957
# 80   4/29/2020              NaN                 Italy     203591   27682
# 229  4/29/2020            Hubei        Mainland China      68128    4512
# 57   4/29/2020              NaN                France     165093   24087
# 167  4/29/2020              NaN                Turkey     117589    3081
# 22   4/29/2020              NaN                Brazil      79685    5513
# 158  4/29/2020              NaN           Switzerland      29407    1716
# 78   4/29/2020              NaN               Ireland      20253    1190
# 8    4/29/2020              NaN               Austria      15402     580
# 107  4/29/2020              NaN                Mexico      17799    1732
# ...

# %% [markdown]
# => Pie Chart of Case Distribution per Region

# %%
import matplotlib.pyplot as plt

# Sample data
total_confirmed = data['Confirmed'].sum()
total_recovered = data['Recovered'].sum()
total_deaths = data['Deaths'].sum()

labels = ['Confirmed', 'Recovered', 'Deaths']
sizes = [total_confirmed, total_recovered, total_deaths]
colors = ['blue', 'green', 'red']

plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', colors=colors, startangle=140)
plt.title('Overall Distribution of COVID-19 Cases')
plt.show()

# %% [markdown]
# => Stacked Bar Chart of COVID-19 Cases by Region

# %%
import matplotlib.pyplot as plt

# Plotting
plt.figure(figsize=(12, 8))
plt.bar(data['Region'], data['Confirmed'], label='Confirmed', color='blue')
plt.bar(data['Region'], data['Recovered'], bottom=data['Confirmed'], label='Recovered', color='green')
plt.bar(data['Region'], data['Deaths'], bottom=data['Confirmed'] + data['Recovered'], label='Deaths', color='red')
plt.xlabel('Region')
plt.ylabel('Number of Cases')
plt.title('Stacked Bar Chart of COVID-19 Cases by Region')
plt.legend()
plt.xticks(rotation=45)

plt.show()
